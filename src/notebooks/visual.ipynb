# %%
import pandas as pd

cols = ['news_id', 'category', 'subcategory', 'title', 'abstract', 'url', 'title_entities', 'abstract_entities']

news_df = pd.read_csv(
    '/home/xuanhau/CodeSpace/freelancer/infor_recommendation/MINDlarge_train/MINDlarge_train/news.tsv',
    sep='\t',
    header=None,
    names=cols,
    usecols=[0, 3, 4],
    dtype=str,
    on_bad_lines='skip'
)

# %%
news_df
# Out:
#         news_id                                              title  \
# 0        N88753  The Brands Queen Elizabeth, Prince Charles, an...
# 1        N45436    Walmart Slashes Prices on Last-Generation iPads
# 2        N23144                      50 Worst Habits For Belly Fat
# 3        N86255  Dispose of unwanted prescription drugs during ...
# 4        N93187  The Cost of Trump's Aid Freeze in the Trenches...
# ...         ...                                                ...
# 101522  N115249  St. Dominic soccer player tries to kick cancer...
# 101523   N64337  Mansion Monday: Contemporary Des Moines home i...
# 101524  N100102                       How the Sounders won MLS Cup
# 101525   N74617                  Best Sports Car Deals for October
# 101526   N56840       Shall we dance: Sports stars shake their leg
#
#                                                  abstract
# 0       Shop the notebooks, jackets, and more that the...
# 1       Apple's new iPad releases bring big deals on l...
# 2       These seemingly harmless habits are holding yo...
# 3                                                     NaN
# 4       Lt. Ivan Molchanets peeked over a parapet of s...
# ...                                                   ...
# 101522  Sometimes, what happens on the sidelines can b...
# 101523  Among the perks of this unique Des Moines home...
# 101524  Mark, Jeremiah and Casey were so excited they ...
# 101525                                                NaN
# 101526                                                NaN
#
# [101527 rows x 3 columns]

# %% [markdown]
# ## READ ENTITY VECTOR

# %%
# read_entity_embedding.py
import numpy as np
from tqdm import tqdm

ENTITY_PATH = "/home/xuanhau/CodeSpace/freelancer/infor_recommendation/MINDlarge_train/MINDlarge_train/entity_embedding.vec"

print("Đang đọc entity_embedding.vec...")
entity2vec = {}
with open(ENTITY_PATH, 'r', encoding='utf-8') as f:
    for line in tqdm(f, total=232554):
        values = line.rstrip().split()
        if len(values) != 101: 
            continue
        entity_id = values[0]
        vector = np.asarray(values[1:], dtype=np.float32)
        entity2vec[entity_id] = vector

print(f"Đã load {len(entity2vec):,} thực thể")
# Test: Apple Inc. → Q312
print("Apple Inc. (Q312):", entity2vec.get("Q312", "Không có")[:5])
# Out:
# Đang đọc entity_embedding.vec...
#   0%|          | 0/232554 [00:00<?, ?it/s]
#  18%|█▊        | 42007/232554 [00:00<00:02, 65725.00it/s]
# Đã load 42,007 thực thể
# Apple Inc. (Q312): [ 0.091596  0.00625   0.08242   0.049334 -0.033524]

# %% [markdown]
# ## LOAD BEHAVIER

# %%
# read_behaviors.py

BEHAVIORS_PATH = "/home/xuanhau/CodeSpace/freelancer/infor_recommendation/MINDlarge_train/MINDlarge_train/behaviors.tsv"

df_behaviors = pd.read_csv(
    BEHAVIORS_PATH,
    sep='\t',
    header=None,
    names=['impression_id', 'user_id', 'time', 'history', 'impressions'],
    dtype=str
)

# %%
df_behaviors = pd.read_csv(
    BEHAVIORS_PATH,
    sep='\t',
    header=None,
    names=['impression_id', 'user_id', 'time', 'history', 'impressions'],
    dtype=str
)
# Out:
#         impression_id  user_id                    time  \
# 0                   1   U87243  11/10/2019 11:30:54 AM
# 1                   2  U598644   11/12/2019 1:45:29 PM
# 2                   3  U532401  11/13/2019 11:23:03 AM
# 3                   4  U593596  11/12/2019 12:24:09 PM
# 4                   5  U239687   11/14/2019 8:03:01 PM
# ...               ...      ...                     ...
# 2232743       2232744  U316192   11/13/2019 6:50:02 PM
# 2232744       2232745  U451238   11/12/2019 8:54:06 AM
# 2232745       2232746  U151246  11/13/2019 12:42:51 PM
# 2232746       2232747  U330725   11/12/2019 1:22:57 PM
# 2232747       2232748  U500938   11/13/2019 8:10:45 PM
#
#                                                    history  \
# 0        N8668 N39081 N65259 N79529 N73408 N43615 N2937...
# 1        N56056 N8726 N70353 N67998 N83823 N111108 N107...
# 2        N128643 N87446 N122948 N9375 N82348 N129412 N5...
# 3        N31043 N39592 N4104 N8223 N114581 N92747 N1207...
# 4        N65250 N122359 N71723 N53796 N41663 N41484 N11...
# ...                                                    ...
# 2232743  N122359 N37069 N95876 N28787 N73408 N11266 N61321
# 2232744                 N12575 N93816 N71643 N87236 N87236
# 2232745                                      N27587 N49668
# 2232746  N121944 N91510 N42280 N60061 N63032 N125223 N4...
# 2232747  N13311 N73573 N36246 N47118 N71728 N105480 N61...
#
#                                                impressions
# 0        N78206-0 N26368-0 N7578-0 N58592-0 N19858-0 N5...
# 1        N47996-0 N82719-0 N117066-0 N8491-0 N123784-0 ...
# 2                    N103852-0 N53474-0 N127836-0 N47925-1
# 3        N38902-0 N76434-0 N71593-0 N100073-0 N108736-0...
# 4        N76209-0 N48841-0 N67937-0 N62235-0 N6307-0 N3...
# ...                                                    ...
# 2232743      N113723-0 N123683-1 N5287-0 N76677-0 N53474-0
# 2232744                 N18861-0 N20990-0 N43085-0 N7937-1
# 2232745  N39887-1 N22811-0 N110709-1 N1923-0 N24001-1 N...
# 2232746  N18947-0 N88808-1 N10012-0 N38902-0 N33078-0 N...
# 2232747  N24701-0 N13161-0 N39403-0 N40310-0 N5287-0 N1...
#
# [2232748 rows x 5 columns]

# %% [markdown]
# ## READ VECTOR SOTA

# %%
import torch

## READ VECTOR SOTA 
SOTA_VECTOR_PATH = "/home/xuanhau/CodeSpace/freelancer/infor_recommendation/processed_data/news2vec_sota.pt"
sota_vectors = torch.load(SOTA_VECTOR_PATH)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       3 ## READ VECTOR SOTA
#       4 SOTA_VECTOR_PATH = "/home/xuanhau/CodeSpace/freelancer/infor_recommendation/processed_data/news2vec_sota.pt"
#
# ModuleNotFoundError: No module named 'torch'
